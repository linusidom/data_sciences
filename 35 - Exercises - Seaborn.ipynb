# %% [markdown]
# # Seaborn Exercises

# %%
# Import the necessary libraries, pandas, numpy, matplotlib and seaborn
# Ensure that we can display plots in the Jupyter Notebook



# Type your code above this line

# %%
# Import the sample Dataset of Tips from seaborn





# Type your code above this line
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Run a pair plot on the data set...do you see any patterns?

# Pair plot runs on quantitative (numerical columns)
# Hue uses categorical data (string data)





# Type your code above this line

# %%
# Run an lmplot between tips and total_bill





# Type your code above this line

# %%
# Run a boxplot between total_bill and day with sex




# Type your code above this line
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Run the same metrics as the box plot but this time run a violinplot




# Type your code above this line
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Run a histogram on a correlated data set




# Type your code above this line
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:>

# %%
# Run a heatmap against the total bill, with the index of the size of the group, between sex and smokers





# Type your code above this line
# Out:
# <AxesSubplot:xlabel='sex-smoker', ylabel='size'>

# %%
# Out:
# <AxesSubplot:xlabel='sex-smoker', ylabel='size'>

# %%
# Run a heatmap against the total bill, with the index of the size of the group, between sex and smokers




# Type your code above this line
