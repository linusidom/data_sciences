# %% [markdown]
# # Supervised Learning Exercises

# %%
# Import the necessary Libraries
# Pandas, Numpy
# SKLearn
# - StandardScaler
# - train_test_split, GridSearchCV
# - confusion_matrix, classification_report, mean_squared_error
# - For the Following import both Regression and Classification
# - Linear
# - K Neighbors
# - Decision Tree
# - Random Forest
# - Support Vector
# - Datasets: fetch_california_housing, load_iris

import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.svm import SVR, SVC

from sklearn.datasets import fetch_california_housing, load_iris







# Type your code above this line

# %% [markdown]
# ### Regression

# %%
# Load the fetch_california_housing data into a DataFrame and add the Target to the the DataFrame


data = fetch_california_housing()

df = pd.DataFrame(data.data, columns=data.feature_names)
df.head()
# data
df[data.target_names[0]] = data.target

df.info()


df[df.isna().any(axis=1)]
# Type your code above this line
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB
# Empty DataFrame
# Columns: [MedInc, HouseAge, AveRooms, AveBedrms, Population, AveOccup, Latitude, Longitude, MedHouseVal]
# Index: []

# %%
# Train Test and Split the data with Standard Scaler
X = df[df.columns[:-1]]
y = df['MedHouseVal']

# Standard scaler

scaler = StandardScaler()
scaler.fit(X)
scaled_X = scaler.transform(X)
X = pd.DataFrame(scaled_X, columns=X.columns)

X.head()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)


# Type your code above this line

# %%
# Create a dictionary with all the algorithms and the necessary tuning parameters called regression_dictionary
# Linear - None
# Neighbors - values 1 to 20
# Decision Tree and Random Forest - Max Depth or 4 and 5
# Support Vector - None

regression_dictionary = {
    
    'linear': {'algorithm': LinearRegression, 'params':{} },
    'neighbor':{'algorithm': KNeighborsRegressor, 'params':{'n_neighbors':range(1,20)} },
    'tree':{'algorithm': DecisionTreeRegressor, 'params':{'max_depth':[4,5]} },
    'random_forest':{'algorithm': RandomForestRegressor, 'params':{} },
    'support_vector':{'algorithm': SVR, 'params':{}},

}






# Type your code above this line

# %%
# Iterate through the regression_dictionary using GridSearchCV
# Fit, predict and evaluate each model


for name, algorithm in regression_dictionary.items():
    print('\n',name.title())
    grid = GridSearchCV(algorithm['algorithm'](), param_grid=algorithm['params'], verbose=3)
    grid.fit(X_train, y_train)
    pred_reg = grid.predict(X_test)
    
    print('Evaluation')
    print('Score', grid.score(X_test, y_test))
    print('RMSE', np.sqrt(mean_squared_error(y_test, pred_reg)))







# Type your code above this line
# Out:
#  Linear
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.605 total time=   0.0s
# [CV 2/5] END ..................................., score=0.603 total time=   0.0s
# [CV 3/5] END ..................................., score=0.617 total time=   0.0s
# [CV 4/5] END ..................................., score=0.611 total time=   0.0s
# [CV 5/5] END ..................................., score=0.597 total time=   0.0s
# Evaluation
# Score 0.5957702326061664
# RMSE 0.7284008391515452
#
#  Neighbor
# Fitting 5 folds for each of 19 candidates, totalling 95 fits
# [CV 1/5] END .....................n_neighbors=1;, score=0.530 total time=   0.1s
# [CV 2/5] END .....................n_neighbors=1;, score=0.506 total time=   0.1s
# [CV 3/5] END .....................n_neighbors=1;, score=0.491 total time=   0.1s
# [CV 4/5] END .....................n_neighbors=1;, score=0.512 total time=   0.1s
# [CV 5/5] END .....................n_neighbors=1;, score=0.513 total time=   0.1s
# [CV 1/5] END .....................n_neighbors=2;, score=0.634 total time=   0.1s
# [CV 2/5] END .....................n_neighbors=2;, score=0.632 total time=   0.1s
# [CV 3/5] END .....................n_neighbors=2;, score=0.613 total time=   0.1s
# [CV 4/5] END .....................n_neighbors=2;, score=0.634 total time=   0.1s
# [CV 5/5] END .....................n_neighbors=2;, score=0.631 total time=   0.1s
# [CV 1/5] END .....................n_neighbors=3;, score=0.661 total time=   0.2s
# [CV 2/5] END .....................n_neighbors=3;, score=0.670 total time=   0.1s
# [CV 3/5] END .....................n_neighbors=3;, score=0.637 total time=   0.1s
# [CV 4/5] END .....................n_neighbors=3;, score=0.667 total time=   0.2s
# [CV 5/5] END .....................n_neighbors=3;, score=0.659 total time=   0.1s
# [CV 1/5] END .....................n_neighbors=4;, score=0.673 total time=   0.2s
# [CV 2/5] END .....................n_neighbors=4;, score=0.681 total time=   0.2s
# [CV 3/5] END .....................n_neighbors=4;, score=0.665 total time=   0.1s
# [CV 4/5] END .....................n_neighbors=4;, score=0.678 total time=   0.2s
# [CV 5/5] END .....................n_neighbors=4;, score=0.667 total time=   0.2s
# [CV 1/5] END .....................n_neighbors=5;, score=0.680 total time=   0.2s
# [CV 2/5] END .....................n_neighbors=5;, score=0.683 total time=   0.2s
# [CV 3/5] END .....................n_neighbors=5;, score=0.672 total time=   0.1s
# [CV 4/5] END .....................n_neighbors=5;, score=0.686 total time=   0.2s
# [CV 5/5] END .....................n_neighbors=5;, score=0.677 total time=   0.2s
# [CV 1/5] END .....................n_neighbors=6;, score=0.680 total time=   0.2s
# [CV 2/5] END .....................n_neighbors=6;, score=0.686 total time=   0.2s
# [CV 3/5] END .....................n_neighbors=6;, score=0.679 total time=   0.1s
# [CV 4/5] END .....................n_neighbors=6;, score=0.687 total time=   0.2s
# [CV 5/5] END .....................n_neighbors=6;, score=0.683 total time=   0.2s
# [CV 1/5] END .....................n_neighbors=7;, score=0.682 total time=   0.2s
# [CV 2/5] END .....................n_neighbors=7;, score=0.686 total time=   0.2s
# [CV 3/5] END .....................n_neighbors=7;, score=0.679 total time=   0.1s
# [CV 4/5] END .....................n_neighbors=7;, score=0.691 total time=   0.2s
# [CV 5/5] END .....................n_neighbors=7;, score=0.689 total time=   0.2s
# [CV 1/5] END .....................n_neighbors=8;, score=0.683 total time=   0.2s
# [CV 2/5] END .....................n_neighbors=8;, score=0.685 total time=   0.2s
# [CV 3/5] END .....................n_neighbors=8;, score=0.684 total time=   0.1s
# [CV 4/5] END .....................n_neighbors=8;, score=0.692 total time=   0.2s
# [CV 5/5] END .....................n_neighbors=8;, score=0.688 total time=   0.2s
# [CV 1/5] END .....................n_neighbors=9;, score=0.683 total time=   0.2s
# [CV 2/5] END .....................n_neighbors=9;, score=0.686 total time=   0.2s
# [CV 3/5] END .....................n_neighbors=9;, score=0.685 total time=   0.1s
# [CV 4/5] END .....................n_neighbors=9;, score=0.691 total time=   0.2s
# [CV 5/5] END .....................n_neighbors=9;, score=0.687 total time=   0.2s
# [CV 1/5] END ....................n_neighbors=10;, score=0.682 total time=   0.2s
# [CV 2/5] END ....................n_neighbors=10;, score=0.688 total time=   0.2s
# [CV 3/5] END ....................n_neighbors=10;, score=0.685 total time=   0.1s
# [CV 4/5] END ....................n_neighbors=10;, score=0.690 total time=   0.3s
# [CV 5/5] END ....................n_neighbors=10;, score=0.686 total time=   0.2s
# [CV 1/5] END ....................n_neighbors=11;, score=0.683 total time=   0.3s
# [CV 2/5] END ....................n_neighbors=11;, score=0.689 total time=   0.2s
# [CV 3/5] END ....................n_neighbors=11;, score=0.689 total time=   0.1s
# [CV 4/5] END ....................n_neighbors=11;, score=0.690 total time=   0.2s
# [CV 5/5] END ....................n_neighbors=11;, score=0.687 total time=   0.2s
# [CV 1/5] END ....................n_neighbors=12;, score=0.681 total time=   0.2s
# [CV 2/5] END ....................n_neighbors=12;, score=0.687 total time=   0.2s
# [CV 3/5] END ....................n_neighbors=12;, score=0.687 total time=   0.1s
# [CV 4/5] END ....................n_neighbors=12;, score=0.690 total time=   0.3s
# [CV 5/5] END ....................n_neighbors=12;, score=0.688 total time=   0.2s
# [CV 1/5] END ....................n_neighbors=13;, score=0.681 total time=   0.2s
# [CV 2/5] END ....................n_neighbors=13;, score=0.686 total time=   0.3s
# [CV 3/5] END ....................n_neighbors=13;, score=0.688 total time=   0.1s
# [CV 4/5] END ....................n_neighbors=13;, score=0.692 total time=   0.3s
# [CV 5/5] END ....................n_neighbors=13;, score=0.688 total time=   0.2s
# [CV 1/5] END ....................n_neighbors=14;, score=0.681 total time=   0.3s
# [CV 2/5] END ....................n_neighbors=14;, score=0.683 total time=   0.3s
# [CV 3/5] END ....................n_neighbors=14;, score=0.688 total time=   0.2s
# [CV 4/5] END ....................n_neighbors=14;, score=0.693 total time=   0.4s
# [CV 5/5] END ....................n_neighbors=14;, score=0.688 total time=   0.3s
# [CV 1/5] END ....................n_neighbors=15;, score=0.680 total time=   0.3s
# [CV 2/5] END ....................n_neighbors=15;, score=0.682 total time=   0.3s
# [CV 3/5] END ....................n_neighbors=15;, score=0.688 total time=   0.2s
# [CV 4/5] END ....................n_neighbors=15;, score=0.693 total time=   0.3s
# [CV 5/5] END ....................n_neighbors=15;, score=0.686 total time=   0.3s
# [CV 1/5] END ....................n_neighbors=16;, score=0.679 total time=   0.3s
# [CV 2/5] END ....................n_neighbors=16;, score=0.681 total time=   0.3s
# [CV 3/5] END ....................n_neighbors=16;, score=0.686 total time=   0.2s
# [CV 4/5] END ....................n_neighbors=16;, score=0.691 total time=   0.3s
# [CV 5/5] END ....................n_neighbors=16;, score=0.687 total time=   0.3s
# [CV 1/5] END ....................n_neighbors=17;, score=0.677 total time=   0.3s
# [CV 2/5] END ....................n_neighbors=17;, score=0.681 total time=   0.3s
# [CV 3/5] END ....................n_neighbors=17;, score=0.688 total time=   0.2s
# [CV 4/5] END ....................n_neighbors=17;, score=0.690 total time=   0.4s
# [CV 5/5] END ....................n_neighbors=17;, score=0.687 total time=   0.3s
# [CV 1/5] END ....................n_neighbors=18;, score=0.678 total time=   0.3s
# [CV 2/5] END ....................n_neighbors=18;, score=0.680 total time=   0.3s
# [CV 3/5] END ....................n_neighbors=18;, score=0.687 total time=   0.2s
# [CV 4/5] END ....................n_neighbors=18;, score=0.691 total time=   0.3s
# [CV 5/5] END ....................n_neighbors=18;, score=0.687 total time=   0.3s
# [CV 1/5] END ....................n_neighbors=19;, score=0.676 total time=   0.3s
# [CV 2/5] END ....................n_neighbors=19;, score=0.679 total time=   0.3s
# [CV 3/5] END ....................n_neighbors=19;, score=0.685 total time=   0.2s
# [CV 4/5] END ....................n_neighbors=19;, score=0.689 total time=   0.4s
# [CV 5/5] END ....................n_neighbors=19;, score=0.686 total time=   0.3s
# Evaluation
# Score 0.6894584983687466
# RMSE 0.6384341595119768
#
#  Tree
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END .......................max_depth=4;, score=0.572 total time=   0.0s
# [CV 2/5] END .......................max_depth=4;, score=0.571 total time=   0.0s
# [CV 3/5] END .......................max_depth=4;, score=0.585 total time=   0.0s
# [CV 4/5] END .......................max_depth=4;, score=0.579 total time=   0.0s
# [CV 5/5] END .......................max_depth=4;, score=0.570 total time=   0.0s
# [CV 1/5] END .......................max_depth=5;, score=0.618 total time=   0.0s
# [CV 2/5] END .......................max_depth=5;, score=0.618 total time=   0.1s
# [CV 3/5] END .......................max_depth=5;, score=0.622 total time=   0.1s
# [CV 4/5] END .......................max_depth=5;, score=0.611 total time=   0.1s
# [CV 5/5] END .......................max_depth=5;, score=0.607 total time=   0.1s
# Evaluation
# Score 0.6029986793705844
# RMSE 0.7218588201173269
#
#  Random_Forest
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.799 total time=   7.5s
# [CV 2/5] END ..................................., score=0.786 total time=   6.4s
# [CV 3/5] END ..................................., score=0.802 total time=   5.9s
# [CV 4/5] END ..................................., score=0.803 total time=   6.2s
# [CV 5/5] END ..................................., score=0.803 total time=   6.5s
# Evaluation
# Score 0.8065838385671672
# RMSE 0.503851634293265
#
#  Support_Vector
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.729 total time=  10.6s
# [CV 2/5] END ..................................., score=0.725 total time=  12.5s
# [CV 3/5] END ..................................., score=0.739 total time=  11.2s
# [CV 4/5] END ..................................., score=0.746 total time=  11.6s
# [CV 5/5] END ..................................., score=0.723 total time=  12.1s
# Evaluation
# Score 0.7355826779866668
# RMSE 0.5891165761911927

# %% [markdown]
# ### Classification

# %%
# Load the load_iris data into a DataFrame and add the Target to the the DataFrame

data = load_iris()

df = pd.DataFrame(data.data, columns=data.feature_names)
df.head()
# data
df['Target'] = data.target

df.info()


df[df.isna().any(axis=1)]



# Type your code above this line
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm), Target]
# Index: []

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['Target Names'] = df['Target'].map({
    0: data.target_names[0] ,
    1: data.target_names[1],
    2: data.target_names[2]
    
})

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Target Target Names
# 0       0       setosa
# 1       0       setosa
# 2       0       setosa
# 3       0       setosa
# 4       0       setosa

# %%
df['Target Names'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: Target Names, dtype: int64

# %%
# Train Test and Split the data with Standard Scaler

X = df[df.columns[:-2]]
y = df['Target']

# Standard scaler

scaler = StandardScaler()
scaler.fit(X)
scaled_X = scaler.transform(X)
X = pd.DataFrame(scaled_X, columns=X.columns)

X.head()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)





# Type your code above this line

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0          -0.900681          1.019004          -1.340227         -1.315444
# 1          -1.143017         -0.131979          -1.340227         -1.315444
# 2          -1.385353          0.328414          -1.397064         -1.315444
# 3          -1.506521          0.098217          -1.283389         -1.315444
# 4          -1.021849          1.249201          -1.340227         -1.315444

# %%
# Create a dictionary with all the algorithms and the necessary tuning parameters called classification_dictionary
# Linear - None
# Neighbors - values 1 to 20
# Decision Tree and Random Forest - Max Depth or 4 and 5
# Support Vector - C values of 1000, 10000000, gamma values of auto and scale

classification_dictionary = {
    
    'linear': {'algorithm': LogisticRegression, 'params':{} },
    'neighbor':{'algorithm': KNeighborsClassifier, 'params':{'n_neighbors':range(1,20)} },
    'tree':{'algorithm': DecisionTreeClassifier, 'params':{'max_depth':[4,5]} },
    'random_forest':{'algorithm': RandomForestClassifier, 'params':{'max_depth':[4,5]} },
    'support_vector':{'algorithm': SVC, 'params':{'C':[1000,10000000], 'gamma':['auto','scale']}},

}






# Type your code above this line

# %%
# Interate through the regression_dictionary using GridSearchCV
# Fit, predict and evaluate each model

for name, algorithm in classification_dictionary.items():
    print('\n', name.title())
    
    grid = GridSearchCV(algorithm['algorithm'](), param_grid=algorithm['params'], verbose=3)
    
    grid.fit(X_train, y_train)
    
    pred_class = grid.predict(X_test)
    
    
    
    print(confusion_matrix(y_test, pred_class))
    print(classification_report(y_test, pred_class))




# Type your code above this line
# Out:
#  Linear
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.952 total time=   0.0s
# [CV 2/5] END ..................................., score=0.905 total time=   0.0s
# [CV 3/5] END ..................................., score=0.905 total time=   0.0s
# [CV 4/5] END ..................................., score=1.000 total time=   0.0s
# [CV 5/5] END ..................................., score=0.952 total time=   0.0s
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
#
#  Neighbor
# Fitting 5 folds for each of 19 candidates, totalling 95 fits
# [CV 1/5] END .....................n_neighbors=1;, score=0.952 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=1;, score=0.905 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=1;, score=0.905 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=1;, score=0.952 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=2;, score=0.952 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=2;, score=0.905 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=2;, score=0.905 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=2;, score=1.000 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=2;, score=0.905 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=3;, score=0.952 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=3;, score=0.952 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=3;, score=0.857 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=3;, score=1.000 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=3;, score=0.952 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=4;, score=0.905 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=4;, score=0.905 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=4;, score=0.857 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=4;, score=1.000 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=4;, score=0.905 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=5;, score=0.905 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=5;, score=0.905 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=5;, score=0.857 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=5;, score=1.000 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=5;, score=0.905 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=6;, score=0.905 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=6;, score=0.905 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=6;, score=0.905 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=6;, score=1.000 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=6;, score=0.905 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=7;, score=0.952 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=7;, score=0.905 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=7;, score=0.857 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=7;, score=1.000 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=7;, score=0.905 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=8;, score=0.952 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=8;, score=0.952 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=8;, score=0.857 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=8;, score=1.000 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=8;, score=0.905 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=9;, score=0.952 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=9;, score=0.905 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=9;, score=0.857 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=9;, score=1.000 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=9;, score=0.905 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=10;, score=0.952 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=10;, score=0.905 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=10;, score=0.905 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=10;, score=1.000 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=10;, score=0.905 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=11;, score=0.952 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=11;, score=0.905 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=11;, score=0.857 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=11;, score=1.000 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=11;, score=0.857 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=12;, score=0.952 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=12;, score=0.905 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=12;, score=0.857 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=12;, score=1.000 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=12;, score=0.810 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=13;, score=0.952 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=13;, score=0.905 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=13;, score=0.857 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=13;, score=1.000 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=13;, score=0.810 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=14;, score=0.952 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=14;, score=0.857 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=14;, score=0.857 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=14;, score=1.000 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=14;, score=0.810 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=15;, score=0.952 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=15;, score=0.857 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=15;, score=0.810 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=15;, score=1.000 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=15;, score=0.810 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=16;, score=0.952 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=16;, score=0.905 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=16;, score=0.810 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=16;, score=1.000 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=16;, score=0.857 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=17;, score=0.952 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=17;, score=0.857 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=17;, score=0.810 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=17;, score=1.000 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=17;, score=0.810 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=18;, score=0.905 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=18;, score=0.762 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=18;, score=0.857 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=18;, score=1.000 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=18;, score=0.810 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=19;, score=0.952 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=19;, score=0.762 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=19;, score=0.857 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=19;, score=1.000 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=19;, score=0.810 total time=   0.0s
# [[19  0  0]
#  [ 0 12  1]
#  [ 0  0 13]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      0.92      0.96        13
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.97        45
# weighted avg       0.98      0.98      0.98        45
#
#
#  Tree
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END .......................max_depth=4;, score=0.952 total time=   0.0s
# [CV 2/5] END .......................max_depth=4;, score=0.905 total time=   0.0s
# [CV 3/5] END .......................max_depth=4;, score=0.905 total time=   0.0s
# [CV 4/5] END .......................max_depth=4;, score=0.952 total time=   0.0s
# [CV 5/5] END .......................max_depth=4;, score=0.952 total time=   0.0s
# [CV 1/5] END .......................max_depth=5;, score=0.952 total time=   0.0s
# [CV 2/5] END .......................max_depth=5;, score=0.905 total time=   0.0s
# [CV 3/5] END .......................max_depth=5;, score=0.905 total time=   0.0s
# [CV 4/5] END .......................max_depth=5;, score=0.952 total time=   0.0s
# [CV 5/5] END .......................max_depth=5;, score=0.905 total time=   0.0s
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
#
#  Random_Forest
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END .......................max_depth=4;, score=0.952 total time=   0.1s
# [CV 2/5] END .......................max_depth=4;, score=0.905 total time=   0.1s
# [CV 3/5] END .......................max_depth=4;, score=0.905 total time=   0.1s
# [CV 4/5] END .......................max_depth=4;, score=1.000 total time=   0.2s
# [CV 5/5] END .......................max_depth=4;, score=0.952 total time=   0.2s
# [CV 1/5] END .......................max_depth=5;, score=0.952 total time=   0.1s
# [CV 2/5] END .......................max_depth=5;, score=0.905 total time=   0.1s
# [CV 3/5] END .......................max_depth=5;, score=0.905 total time=   0.1s
# [CV 4/5] END .......................max_depth=5;, score=1.000 total time=   0.1s
# [CV 5/5] END .......................max_depth=5;, score=0.952 total time=   0.1s
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
#
#  Support_Vector
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END ................C=1000, gamma=auto;, score=0.905 total time=   0.0s
# [CV 2/5] END ................C=1000, gamma=auto;, score=0.857 total time=   0.0s
# [CV 3/5] END ................C=1000, gamma=auto;, score=0.905 total time=   0.0s
# [CV 4/5] END ................C=1000, gamma=auto;, score=1.000 total time=   0.0s
# [CV 5/5] END ................C=1000, gamma=auto;, score=0.952 total time=   0.0s
# [CV 1/5] END ...............C=1000, gamma=scale;, score=0.905 total time=   0.0s
# [CV 2/5] END ...............C=1000, gamma=scale;, score=0.857 total time=   0.0s
# [CV 3/5] END ...............C=1000, gamma=scale;, score=0.905 total time=   0.0s
# [CV 4/5] END ...............C=1000, gamma=scale;, score=1.000 total time=   0.0s
# [CV 5/5] END ...............C=1000, gamma=scale;, score=0.952 total time=   0.0s
# [CV 1/5] END ............C=10000000, gamma=auto;, score=0.905 total time=   0.0s
# [CV 2/5] END ............C=10000000, gamma=auto;, score=0.857 total time=   0.0s
# [CV 3/5] END ............C=10000000, gamma=auto;, score=0.905 total time=   0.0s
# [CV 4/5] END ............C=10000000, gamma=auto;, score=1.000 total time=   0.0s
# [CV 5/5] END ............C=10000000, gamma=auto;, score=0.952 total time=   0.0s
# [CV 1/5] END ...........C=10000000, gamma=scale;, score=0.905 total time=   0.0s
# [CV 2/5] END ...........C=10000000, gamma=scale;, score=0.857 total time=   0.0s
# [CV 3/5] END ...........C=10000000, gamma=scale;, score=0.905 total time=   0.0s
# [CV 4/5] END ...........C=10000000, gamma=scale;, score=1.000 total time=   0.0s
# [CV 5/5] END ...........C=10000000, gamma=scale;, score=0.952 total time=   0.0s
# [[19  0  0]
#  [ 0 12  1]
#  [ 0  1 12]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.92      0.92      0.92        13
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45
